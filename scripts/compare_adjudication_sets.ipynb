# %%
import pandas as pd

subset2 = pd.read_json("../inputs/ume-adjudication/subset-2.jsonl", lines=True)
examples = pd.read_json("../data/ume-final.jsonl", lines=True)
examples["_timestamp"] = pd.to_datetime(examples["_timestamp"], unit='s')
subset1b = pd.read_csv("../data/Mar6data_ToAdjudicate.csv")
subset2
# Out:
#      idx                                           question  \
# 0      1  A theater charges a \$12 booking fee plus \$4 ...
# 1     12  The attendance $A(w)$, in hundreds of people, ...
# 2     16  A real estate agent analyzes the relationship ...
# 3     28  Two equilateral triangles are similar, with th...
# 4     29  The equation $4x + 6y = 24$ can be rewritten a...
# ..   ...                                                ...
# 126  834  A planetary gear in a watch mechanism rotates ...
# 127  836  A salesperson earns a monthly base salary of \...
# 128  896  A bakery sells two sizes of muffins. A custome...
# 129  902  The table below shows selected values for the ...
# 130  905  A school sells tickets to a play. For every \$...
#
#                                               choice_A  \
# 0                                                   20
# 1    The y-intercept represents 30 hundred people a...
# 2                                 An increase of \$250
# 3                                                $0.5$
# 4                                                $2/3$
# ..                                                 ...
# 126                                           $2\pi/3$
# 127                                           \$14,000
# 128                                             \$2.75
# 129                                           $2x - 1$
# 130                                               \$10
#
#                                               choice_B  \
# 0                                                   23
# 1    The y-intercept represents 12 hundred people a...
# 2                                An increase of \$3000
# 3                                                $1.5$
# 4                                                $3/2$
# ..                                                 ...
# 126                                           $3\pi/4$
# 127                                           \$20,667
# 128                                             \$3.75
# 129                                      $x^2 + x - 1$
# 130                                               \$14
#
#                                               choice_C  \
# 0                                                   26
# 1    The y-intercept represents approximately 13.7 ...
# 2                                 A decrease of \$3000
# 3                                                  $2$
# 4                                               $-2/3$
# ..                                                 ...
# 126                                           $4\pi/3$
# 127                                           \$74,000
# 128                                                \$4
# 129                                        $2^{x} - 2$
# 130                                               \$20
#
#                                               choice_D correct_answer  \
# 0                                                   80              A
# 1    The y-intercept represents 12 hundred people a...              D
# 2                                  A decrease of \$250              D
# 3                                                  $4$              C
# 4                                                $4/6$              C
# ..                                                 ...            ...
# 126                                           $8\pi/3$              C
# 127                                              \$840              A
# 128                                                \$5              B
# 129                                    $2^{x + 1} - 3$              D
# 130                                               \$15              D
#
#                                 domain  \
# 0                              Algebra
# 1                        Advanced Math
# 2    Problem-Solving and Data Analysis
# 3            Geometry and Trigonometry
# 4                              Algebra
# ..                                 ...
# 126          Geometry and Trigonometry
# 127                            Algebra
# 128                            Algebra
# 129                      Advanced Math
# 130                      Advanced Math
#
#                                                 label  \
# 0                   Linear equations in two variables
# 1                                 Nonlinear Functions
# 2         Two-Variable Data - Models and Scatterplots
# 3                        Lines, angles, and triangles
# 4                   Linear equations in two variables
# ..                                                ...
# 126                                           Circles
# 127                  Linear equations in one variable
# 128  Systems of two linear equations in two variables
# 129                               Nonlinear Functions
# 130                               Nonlinear Functions
#
#                                                   task  ...  \
# 0    For a linear equation in two variables that re...  ...
# 1    Understand and use the fact that for the graph...  ...
# 2    Fit linear models to data represented in a sca...  ...
# 3    Apply knowledge that changing by a scale facto...  ...
# 4    Make connections between an algebraic represen...  ...
# ..                                                 ...  ...
# 126  Convert between angle measures in degrees and ...  ...
# 127  Fluently solve a linear equation in one variable.  ...
# 128  Solve a system of two linear equations in two ...  ...
# 129  Make connections between a table, an algebraic...  ...
# 130  Create and use quadratic or exponential functi...  ...
#
#                                          question_orig  \
# 0    A theater charges a \$12 booking fee plus \$4 ...
# 1    The attendance $A(w)$, in hundreds of people, ...
# 2    A real estate agent analyzes the relationship ...
# 3    Two equilateral triangles are similar, with th...
# 4    The equation $4x + 6y = 24$ can be rewritten a...
# ..                                                 ...
# 126  A gear in a watch mechanism rotates $240^{\cir...
# 127  A salesperson earns a monthly base salary of \...
# 128  A bakery sells two sizes of muffins. A custome...
# 129  The table below shows selected values for the ...
# 130  A school sells tickets to a play. For every \$...
#
#                                          choice_A_orig  \
# 0                                                   20
# 1    The y-intercept represents 30 hundred people a...
# 2                                 An increase of \$250
# 3                                                $0.5$
# 4                                $m = 2/3$ and $b = 6$
# ..                                                 ...
# 126                                           $2\pi/3$
# 127                                     \14,000 snacks
# 128                                                \$2
# 129                                      $f(x)=2x - 1$
# 130                                               \$10
#
#                                          choice_B_orig  \
# 0                                                   23
# 1    The y-intercept represents 12 hundred people a...
# 2                                An increase of \$3000
# 3                                                $1.5$
# 4                                $m = 3/2$ and $b = 4$
# ..                                                 ...
# 126                                           $3\pi/4$
# 127                                     \20,667 snacks
# 128                                                \$3
# 129                                 $f(x)=x^2 + x - 1$
# 130                                               \$14
#
#                                          choice_C_orig  \
# 0                                                   26
# 1    The y-intercept represents 8.7 hundred people ...
# 2                                 A decrease of \$3000
# 3                                                  $2$
# 4                               $m = -2/3$ and $b = 4$
# ..                                                 ...
# 126                                           $4\pi/3$
# 127                                     \74,000 snacks
# 128                                                \$4
# 129                                   $f(x)=2^{x} - 2$
# 130                                               \$20
#
#                                          choice_D_orig topic vocabulary  \
# 0                                                   80   3.0        3.0
# 1    The y-intercept represents 12 hundred people a...   3.0        3.0
# 2                                  A decrease of \$250   3.0        3.0
# 3                                                  $4$   3.0        2.0
# 4                                $m = 4/6$ and $b = 4$   3.0        3.0
# ..                                                 ...   ...        ...
# 126                                           $8\pi/3$   3.0        3.0
# 127                                        \840 snacks   2.0        2.0
# 128                                                \$5   3.0        3.0
# 129                               $f(x)=2^{x + 1} - 3$   3.0        3.0
# 130                                               \$15   2.0        1.0
#
#     choices  overall  answer
# 0       3.0        2  accept
# 1       2.0        2  accept
# 2       3.0        3  accept
# 3       3.0        2  accept
# 4       3.0        3  accept
# ..      ...      ...     ...
# 126     3.0        2  accept
# 127     3.0        2  accept
# 128     1.0        2  accept
# 129     3.0        3  accept
# 130     3.0        2  accept
#
# [131 rows x 23 columns]

# %%
a = set(subset2["idx"])
b = set(subset1b["idx"])
diff = sorted(list(a.symmetric_difference(b)))
print("Symmetric diff: ", diff)
only_a = sorted(list(a.difference(b)))
print("Only in A: ", only_a)
only_b = sorted(list(b.difference(a)))
print("Only in B: ", len(only_b))
# Out:
# Symmetric diff:  [1, 12, 16, 28, 29, 38, 39, 51, 55, 62, 79, 80, 92, 94, 95, 100, 113, 117, 123, 127, 131, 142, 146, 152, 187, 196, 205, 216, 223, 232, 264, 270, 287, 300, 311, 313, 314, 316, 337, 344, 348, 354, 363, 369, 377, 385, 387, 391, 403, 408, 416, 430, 442, 446, 448, 449, 453, 461, 462, 471, 472, 479, 484, 489, 493, 495, 497, 500, 502, 504, 505, 508, 509, 510, 512, 513, 514, 516, 519, 520, 521, 527, 529, 530, 531, 532, 533, 537, 538, 539, 541, 547, 553, 557, 560, 562, 564, 566, 567, 568, 569, 572, 573, 575, 579, 580, 584, 586, 588, 590, 591, 592, 593, 598, 601, 602, 604, 609, 614, 615, 616, 618, 620, 622, 623, 627, 632, 636, 637, 638, 640, 644, 645, 646, 648, 649, 650, 651, 652, 655, 656, 657, 659, 660, 661, 664, 671, 674, 678, 679, 681, 684, 686, 687, 697, 699, 701, 702, 703, 704, 707, 708, 709, 711, 720, 724, 731, 734, 740, 750, 751, 761, 764, 767, 768, 772, 776, 779, 784, 787, 794, 798, 806, 834, 836, 896, 902, 905]
# Only in A:  [1, 12, 16, 28, 29, 38, 39, 51, 55, 62, 79, 80, 92, 94, 95, 100, 113, 117, 123, 127, 131, 142, 146, 152, 187, 196, 205, 216, 223, 232, 264, 270, 287, 300, 311, 313, 314, 316, 337, 344, 348, 354, 363, 369, 377, 385, 387, 391, 403, 408, 416, 430, 442, 446, 448, 449, 453, 461, 462, 472, 479, 484, 493, 495, 500, 502, 505, 510, 512, 516, 519, 520, 521, 527, 530, 531, 532, 538, 562, 566, 573, 580, 590, 593, 598, 604, 614, 618, 620, 622, 623, 632, 636, 644, 657, 660, 661, 664, 674, 678, 679, 697, 701, 703, 704, 709, 711, 720, 724, 731, 734, 740, 750, 751, 761, 764, 767, 768, 772, 776, 779, 784, 787, 794, 798, 806, 834, 836, 896, 902, 905]
# Only in B:  57
